# %%
print("hello, world")
# Out:
# hello, world

# %%
nome = "Gustavo"

# %%
idade = 14

# %%
altura = 1.65

# %%
gosta_de_programar = True

# %%
print(f"Meu nome é {nome}, tenho {idade}, {altura} metros e gosto de programar?{gosta_de_programar}")
# Out:
# Meu nome é Gustavo, tenho 14, 1.65 metros e gosto de programar?True

# %%
print(type(nome))
# Out:
# <class 'str'>

# %%
print(type(idade))
# Out:
# <class 'int'>

# %%
print(type(altura))
# Out:
# <class 'float'>

# %%
print(type(gosta_de_programar))
# Out:
# <class 'bool'>

# %%
preço_apple = 189.50

# %%
acoes = 3

# %%
total = preço_apple * acoes

# %%
print(f"Você comprou", acoes, "acoes da apple.")
# Out:
# Você comprou 3 acoes da apple.

# %%
print(f"Você comprou {acoes} acoes da applee gastou {total} doláres.")
# Out:
# Você comprou 3 acoes da applee gastou 568.5 doláres.

# %%
print(f"Total gasto: {total:.2f}")
# Out:
# Total gasto: 568.50
