# %%
c=1
while c < 10:
  print(c)
  c = c + 1
print("Fim!")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# Fim!

# %%
r = "S"
while r == "S":
  n = int(input("Digite um número: "))
  r = str(input("Quer continuar? [S/N] ")).upper()
print("Fim!")
# Out:
# Digite um número: 1
# Quer continuar? [S/N] s
# Digite um número: 2
# Quer continuar? [S/N] s
# Digite um número: 3
# Quer continuar? [S/N] n
# Fim!

# %%
n = 1
par = ímpar = 0
while n != 0:
  n = int(input("Digite um valor: "))
  if n != 0:
    if n % 2 == 0:
      par += 1
    else:
      ímpar += 1
print("Você digitou {} números pares e {} números ímpares".format(par, ímpar))
# Out:
# Digite um valor: 1
# Digite um valor: 2
# Digite um valor: 3
# Digite um valor: 4
# Digite um valor: 5
# Digite um valor: 6
# Digite um valor: 7
# Digite um valor: 8
# Digite um valor: 9
# Digite um valor: 10
# Digite um valor: 0
# Você digitou 5 números pares e 5 números ímpares

# %%
contador = 0
soma = 0
pares = 0
ímpar = 0
maior = None
menor = None
while True:
  numero = int(input("Digite um número(0 para parar): "))
  if numero == 0:
    break
  contador += 1
  soma += numero
  if numero % 2 == 0:
    pares += 1
  else:
    ímpar += 1
  if maior is None or numero > maior:
    maior = numero
  if menor is None or numero < menor:
    menor = numero

if contador > 0:
  media = soma / contador
  print("\n📌 Resultados")
  print("Quantidade de números digitados: ", contador)
  print("Soma total: ", soma)
  print("Média: ", media)
  print("Maior número: ", maior)
  print("Menor número: ", menor)
  print("Quantida de pares: ", pares)
  print("Quantidade de ímpares: ", ímpar)
else:
  print("Você não digitou nenhum número. Tente novamente.")
while True:
  reiniciar = input("\nDeseja reiniciar o programa? [S/N] ").strip().lower()
  if reiniciar == "s" or reiniciar == "n":
    if reiniciar == "n":
      print("Programa encerrado.")
      break
    else:
      break
  else:
    print("Opção inválida. Tente novamente digitando apenas 's' ou 'n'.")
# Out:
# Digite um número(0 para parar): 10
# Digite um número(0 para parar): 9
# Digite um número(0 para parar): 8
# Digite um número(0 para parar): 7
# Digite um número(0 para parar): 6
# Digite um número(0 para parar): 5
# Digite um número(0 para parar): 4
# Digite um número(0 para parar): 3
# Digite um número(0 para parar): 2
# Digite um número(0 para parar): 1
# Digite um número(0 para parar): 0
#
# 📌 Resultados
# Quantidade de números digitados:  10
# Soma total:  55
# Média:  5.5
# Maior número:  10
# Menor número:  1
# Quantida de pares:  5
# Quantidade de ímpares:  5
#
# Deseja reiniciar o programa? [S/N] n
# Programa encerrado.
