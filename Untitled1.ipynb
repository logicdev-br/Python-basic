# %%
nome = input("Qual seu nome?")
# Out:
# Qual seu nome?Gustavo

# %%
idade = int(input("Qual sua idade?"))
# Out:
# Qual sua idade?14

# %%
print(f"olá {nome}, você tem {idade} anos.")
# Out:
# olá Gustavo, você tem 14 anos.

# %%
numero1 = float(input("Digite um numero: "))
# Out:
# Digite um numero: 30

# %%
numero2 = float(input("Digite outro numero: "))
# Out:
# Digite outro numero: 20

# %%
soma = numero1 + numero2

# %%
print(f"A soma é {soma}")
# Out:
# A soma é 50.0

# %%
idade = int(input("Digite sua idade: "))
# Out:
# Digite sua idade: 14

# %%
print(f"Daqui 5 anos você terá {idade + 5} anos")
# Out:
# Daqui 5 anos você terá 19 anos

# %%
nome = input("Digite seu nome: ")
# Out:
# Digite seu nome: Gustavo

# %%
idade = int(input("Digite sua idade"))
# Out:
# Digite sua idade14

# %%
altura = float(input("Digite sua altura"))
# Out:
# Digite sua altura1.65

# %%
print(f"Seu nome é {nome}, você tem {idade} anos e mede {altura}m.")
# Out:
# Seu nome é Gustavo, você tem 14 anos e mede 1.65m.

# %%
print(f"No ano que vem você terá {idade + 1} anos.")
# Out:
# No ano que vem você terá 15 anos.

# %%
print(f"No ano que vem você terá altura {altura * 100}cm.")
# Out:
# No ano que vem você terá altura 165.0cm.
